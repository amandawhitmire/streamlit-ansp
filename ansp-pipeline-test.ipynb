# %% [markdown]
# ## Testing code used in my ANSP Streamlit app
#
# Below is literally the _exact same code_ as in my Streamlit app file `app.py` (with the exception of the displacy stuff at the end). This all WORKS. The Streamlit app DOESN'T. Specifically, the Streamlit app fails to import the Entity Ruler (or imports it but fails to use it). The Streamlit app does not throw an error, it just seems to ignore my efforts to add an Entity Ruler to the pipeline. RUDE.

# %%
# load packages 

import spacy
from pathlib import Path
import srsly
import importlib
import random
from spacy.pipeline import EntityRuler # Import the Entity Ruler for making custom entities
from spacy.language import Language  # type: ignore 
import json
# Import the spaCy visualizer
from spacy import displacy

# %%
# streamlit setup stuff
MODELS = srsly.read_json("/Users/thalassa/streamlit/streamlit-ansp/models.json")
DEFAULT_MODEL = "en_core_web_sm"
DEFAULT_TEXT =  "Frances Naomi Clark was an American ichthyologist born in 1894, and was one of the first woman fishery researchers to receive world-wide recognition. Frances Naomi Clark was an American ichthyologist born in 1894, and was one of the first woman fishery researchers to receive world-wide recognition. Seven Ampelis cedrorum specimens were collected in a meadow near lowland fruit trees. Some habitats we know are in the json file are near large rocks, near river mouths, near the bottom and near the ocean. Some species names are Hemigrapsus affinis, Hemigrapsus crassimanus, Hendersonia alternifoliae and Hendersonia celtifolia."
DESCRIPTION = """**Explore trained [spaCy v3.0](https://nightly.spacy.io) pipelines with the Proceedings of the Academy of Natural Sciences of Philadelphia**"""

# %%
text = DEFAULT_TEXT
    # doc = spacy_streamlit.process_text(NLP, text)

nlp = spacy.load(DEFAULT_MODEL)
ruler = nlp.add_pipe("entity_ruler", before='ner')
ruler.from_disk("/Users/thalassa/streamlit/streamlit-ansp/ansp-patterns.jsonl")

# %%
# Check the pipeline. The entity_ruler should happen *before* ner.
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7fbf40f19310>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7fbf27a30220>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7fbf41c64880>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7fbf272aef40>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7fbf272c5e80>),
#  ('entity_ruler', <spacy.pipeline.entityruler.EntityRuler at 0x7fbf273c5fc0>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7fbf41c64640>)]

# %%
doc = nlp(text)

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Frances Naomi Clark 0 19 PERSON
# American 27 35 NORP
# 1894 58 62 DATE
# one 72 75 CARDINAL
# Frances Naomi Clark 150 169 PERSON
# American 177 185 NORP
# 1894 208 212 DATE
# one 222 225 CARDINAL
# Seven 300 305 CARDINAL
# Ampelis cedrorum 306 322 TAXA
# lowland fruit trees 365 384 HABITAT
# near large rocks 433 449 HABITAT
# near river mouths 451 468 HABITAT
# near the bottom 470 485 HABITAT
# near the ocean 490 504 HABITAT
# Hemigrapsus affinis 529 548 TAXA
# Hemigrapsus crassimanus 550 573 TAXA
# Hendersonia alternifoliae 575 600 TAXA
# Hendersonia celtifolia 605 627 TAXA

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)

# %%
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frances Naomi Clark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  ichthyologist born in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1894
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the first woman fishery researchers to receive world-wide recognition.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frances Naomi Clark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  ichthyologist born in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1894
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the first woman fishery researchers to receive world-wide recognition.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seven
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ampelis cedrorum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TAXA</span>
# </mark>
#  specimens were collected in a meadow near
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lowland fruit trees
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">HABITAT</span>
# </mark>
# . Some habitats we know are in the json file are
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     near large rocks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">HABITAT</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     near river mouths
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">HABITAT</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     near the bottom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">HABITAT</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     near the ocean
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">HABITAT</span>
# </mark>
# . Some species names are
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hemigrapsus affinis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TAXA</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hemigrapsus crassimanus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TAXA</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hendersonia alternifoliae
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TAXA</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hendersonia celtifolia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TAXA</span>
# </mark>
# .</div></span>

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Frances Frances PROPN NNP compound Xxxxx True False
# Naomi Naomi PROPN NNP compound Xxxxx True False
# Clark Clark PROPN NNP nsubj Xxxxx True False
# was be AUX VBD ROOT xxx True True
# an an DET DT det xx True True
# American american ADJ JJ amod Xxxxx True False
# ichthyologist ichthyologist NOUN NN attr xxxx True False
# born bear VERB VBN acl xxxx True False
# in in ADP IN prep xx True True
# 1894 1894 NUM CD pobj dddd False False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# was be VERB VBD conj xxx True True
# one one NUM CD attr xxx True True
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# first first ADJ JJ amod xxxx True True
# woman woman NOUN NN compound xxxx True False
# fishery fishery NOUN NN compound xxxx True False
# researchers researcher NOUN NNS pobj xxxx True False
# to to PART TO aux xx True True
# receive receive VERB VB xcomp xxxx True False
# world world NOUN NN npadvmod xxxx True False
# - - PUNCT HYPH punct - False False
# wide wide ADJ JJ amod xxxx True False
# recognition recognition NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
# Frances france NOUN NNS compound Xxxxx True False
# Naomi Naomi PROPN NNP compound Xxxxx True False
# Clark Clark PROPN NNP nsubj Xxxxx True False
# was be AUX VBD ROOT xxx True True
# an an DET DT det xx True True
# American american ADJ JJ amod Xxxxx True False
# ichthyologist ichthyologist NOUN NN attr xxxx True False
# born bear VERB VBN acl xxxx True False
# in in ADP IN prep xx True True
# 1894 1894 NUM CD pobj dddd False False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# was be VERB VBD conj xxx True True
# one one NUM CD attr xxx True True
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# first first ADJ JJ amod xxxx True True
# woman woman NOUN NN compound xxxx True False
# fishery fishery NOUN NN compound xxxx True False
# researchers researcher NOUN NNS pobj xxxx True False
# to to PART TO aux xx True True
# receive receive VERB VB xcomp xxxx True False
# world world NOUN NN npadvmod xxxx True False
# - - PUNCT HYPH punct - False False
# wide wide ADJ JJ amod xxxx True False
# recognition recognition NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
# Seven seven NUM CD nummod Xxxxx True False
# Ampelis Ampelis PROPN NNP compound Xxxxx True False
# cedrorum cedrorum NOUN NN compound xxxx True False
# specimens specimen NOUN NNS nsubjpass xxxx True False
# were be AUX VBD auxpass xxxx True True
# collected collect VERB VBN ROOT xxxx True False
# in in ADP IN prep xx True True
# a a DET DT det x True True
# meadow meadow NOUN NN pobj xxxx True False
# near near SCONJ IN prep xxxx True False
# lowland lowland PROPN NNP compound xxxx True False
# fruit fruit NOUN NN compound xxxx True False
# trees tree NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# Some some DET DT det Xxxx True True
# habitats habitat NOUN NNS nsubj xxxx True False
# we we PRON PRP nsubj xx True True
# know know VERB VBP parataxis xxxx True False
# are be VERB VBP csubj xxx True True
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# json json NOUN NN compound xxxx True False
# file file NOUN NN pobj xxxx True False
# are be AUX VBP ROOT xxx True True
# near near SCONJ IN prep xxxx True False
# large large ADJ JJ amod xxxx True False
# rocks rock NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# near near SCONJ IN prep xxxx True False
# river river NOUN NN compound xxxx True False
# mouths mouth NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# near near SCONJ IN prep xxxx True False
# the the DET DT det xxx True True
# bottom bottom NOUN NN pobj xxxx True True
# and and CCONJ CC cc xxx True True
# near near SCONJ IN conj xxxx True False
# the the DET DT det xxx True True
# ocean ocean NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Some some DET DT det Xxxx True True
# species species NOUN NN compound xxxx True False
# names name NOUN NNS nsubj xxxx True False
# are be AUX VBP ROOT xxx True True
# Hemigrapsus Hemigrapsus PROPN NNP compound Xxxxx True False
# affinis affini NOUN NNS attr xxxx True False
# , , PUNCT , punct , False False
# Hemigrapsus Hemigrapsus PROPN NNP compound Xxxxx True False
# crassimanus crassimanus NOUN NN attr xxxx True False
# , , PUNCT , punct , False False
# Hendersonia Hendersonia PROPN NNP compound Xxxxx True False
# alternifoliae alternifoliae PROPN NNP appos xxxx True False
# and and CCONJ CC cc xxx True True
# Hendersonia Hendersonia PROPN NNP compound Xxxxx True False
# celtifolia celtifolia NOUN NNS conj xxxx True False
# . . PUNCT . punct . False False

# %%
displacy.render(doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b3b3f031a96745609c3159c4646976c1-0" class="displacy" width="17025" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Frances</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Naomi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Clark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">American</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">ichthyologist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">born</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">1894,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">woman</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">fishery</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">researchers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">receive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">world-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">wide</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">recognition.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Frances</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Naomi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">Clark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">American</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">ichthyologist</tspan>
#     <tspan class="displacy-tag" dy="
